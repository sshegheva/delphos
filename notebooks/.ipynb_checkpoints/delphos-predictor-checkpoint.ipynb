# %%
# %matplotlib inline

# %%
import sys
import nltk
sys.path.append('/Users/sshegheva/workspace/delphos')
import pandas as pd
import numpy as np
from delphos.finalist_predictor import feature_transform
reload(feature_transform)
# Out:
# <module 'delphos.finalist_predictor.feature_transform' from '/Users/sshegheva/workspace/delphos/delphos/finalist_predictor/feature_transform.pyc'>

# %%
data = './data/innovations/'

# %%
inno_frame = feature_transform.create_innovation_frame(data)
# Out:
# DEBUG:delphos.finalist_predictor.feature_transform:Parsing ./data/innovations/inno10.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-179b3c920fc5> in <module>()
# ----> 1 inno_frame = feature_transform.create_innovation_frame(data)
#
# /Users/sshegheva/workspace/delphos/delphos/finalist_predictor/feature_transform.pyc in create_innovation_frame(data_path)
#     150 def create_innovation_frame(data_path):
#     151     data_files = glob.glob(data_path + '/*.csv')
# --> 152     frames = [FeatureExtractor(f).df for f in data_files]
#     153     return pd.concat(frames)
#
# /Users/sshegheva/workspace/delphos/delphos/finalist_predictor/feature_transform.pyc in __init__(self, innovation_csv)
#      48         self.name = self.csv.split('.')[0]
#      49         self.df = pd.read_csv(self.csv)
# ---> 50         self._parse_features()
#      51         self._drop_noise()
#      52         LOGGER.debug('Parsed {}'.format(innovation_csv))
#
# /Users/sshegheva/workspace/delphos/delphos/finalist_predictor/feature_transform.pyc in _parse_features(self)
#      60         self.create_is_demo_feature()
#      61         self.create_judges_feature()
# ---> 62         self.create_location_feature()
#      63         self.create_place_feature()
#      64         self.create_presentation_image_feature()
#
# /Users/sshegheva/workspace/delphos/delphos/finalist_predictor/feature_transform.pyc in create_location_feature(self)
#      98
#      99     def create_location_feature(self):
# --> 100         self.df[LOCATION] = self.df['Project Home Base (NYC, Bos, Germany, etc.)']
#     101         self._drop_column('Project Home Base (NYC, Bos, Germany, etc.)')
#     102
#
# /Users/sshegheva/anaconda/lib/python2.7/site-packages/pandas-0.14.0-py2.7-macosx-10.5-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1682             return self._getitem_multilevel(key)
#    1683         else:
# -> 1684             return self._getitem_column(key)
#    1685
#    1686     def _getitem_column(self, key):
#
# /Users/sshegheva/anaconda/lib/python2.7/site-packages/pandas-0.14.0-py2.7-macosx-10.5-x86_64.egg/pandas/core/frame.pyc in _getitem_column(self, key)
#    1689         # get column
#    1690         if self.columns.is_unique:
# -> 1691             return self._get_item_cache(key)
#    1692
#    1693         # duplicate columns & possible reduce dimensionaility
#
# /Users/sshegheva/anaconda/lib/python2.7/site-packages/pandas-0.14.0-py2.7-macosx-10.5-x86_64.egg/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1050         res = cache.get(item)
#    1051         if res is None:
# -> 1052             values = self._data.get(item)
#    1053             res = self._box_item_values(item, values)
#    1054             cache[item] = res
#
# /Users/sshegheva/anaconda/lib/python2.7/site-packages/pandas-0.14.0-py2.7-macosx-10.5-x86_64.egg/pandas/core/internals.pyc in get(self, item)
#    2535
#    2536             if not isnull(item):
# -> 2537                 loc = self.items.get_loc(item)
#    2538             else:
#    2539                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/sshegheva/anaconda/lib/python2.7/site-packages/pandas-0.14.0-py2.7-macosx-10.5-x86_64.egg/pandas/core/index.pyc in get_loc(self, key)
#    1154         loc : int if unique index, possibly slice or mask if not
#    1155         """
# -> 1156         return self._engine.get_loc(_values_from_object(key))
#    1157
#    1158     def get_value(self, series, key):
#
# index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3353)()
#
# index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3233)()
#
# hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11148)()
#
# hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11101)()
#
# KeyError: 'Project Home Base (NYC, Bos, Germany, etc.)'

# %%
f = 'inno8.csv'

# %%
df = pd.read_csv('data/innovations/inno10.csv')

# %%
df.
# Out:
#                                        \n  \
# 0                               Team Name
# 1                                 B2Beast
# 2                                Cloud DB
# 3                                   Couch
# 4                        Daily Delta Data
# 5                                 Delphos
# 6                               Doctor Xu
# 7                        Drag and Drop UI
# 8              Drive It Like You Stole It
# 9                             DX Co-Pilot
# 10                             DXPolitics
# 11                         Easy Analytics
# 12                            ELK for CMS
# 13                      Eternal Optimists
# 14                               FairPlay
# 15                               Hello UI
# 16                            IP Expander
# 17                          JIRA Planning
# 18  Mythical Man Month Mathematical Model
# 19                   Native Open Creative
# 20                                Octopus
# 21               Omnichannel DCO Solution
# 22                   Rate Cards, Finally!
# 23         Retargeting Performance Alerts
# 24                                 Rocket
# 25                Sales. Insight. Action.
# 26                               Sherlock
# 27                   The Alpha Impression
# 28                             The Clicks
# 29                       Valar Occurremus
# 30                     Vertical Knowledge
# 31
#
#                                      Unnamed: 1          Unnamed: 2  \
# 0   Project Home Base (NYC, Bos, Germany, etc.)  Session Assignment
# 1                                        Boston            BOS-Blue
# 2                                        Boston            BOS-Blue
# 3                                     Bangalore                APAC
# 4                                        Boston             BOS-Red
# 5                             Boston/Montevideo           BOS-Green
# 6                                        Boston             BOS-Red
# 7                                        Boston                 NaN
# 8                                       Chicago                 NaN
# 9                           Boston / Montevideo           BOS-Green
# 10                                       Boston             BOS-Red
# 11                                       Boston             BOS-Red
# 12                                       Boston
# 13                                       Boston             BOS-Red
# 14                                       London               EU/UK
# 15                                       London               EU/UK
# 16                                    Singapore                APAC
# 17                     Boston - executed Remote           BOS-Green
# 18                                       Boston            BOS-Blue
# 19                                                        BOS-Green
# 20                                       Boston             BOS-Red
# 21                                      Cologne               EU/UK
# 22                                       Boston
# 23                                       Boston
# 24                                    Bangalore                APAC
# 25                                       Boston           BOS-Green
# 26                                       Boston            BOS-Blue
# 27                                San Francisco             US-West
# 28                                       Boston             BOS-Red
# 29                              Boston (remote)           BOS-Green
# 30                      Braavos (San Francisco)             US-West
# 31                                       Boston            BOS-Blue
#
#          Unnamed: 3                                         Unnamed: 4  \
# 0   Classic or GSD?  Quick Description of the project (for recruiti...
# 1           Classic             Enhanced solution for B2B/IP targeting
# 2               GSD  Create a multi-node greenplum cluster in AWS. ...
# 3           Classic                   Running Virtual test lab locally
# 4               GSD  Gather history of daily delta check and store ...
# 5           Classic  As DataXu grows, we need to be able to scale l...
# 6               GSD  Tool suite to test, audit, and fix creative ta...
# 7               GSD  Create a web based graphical user interface th...
# 8               GSD  Create "ASAP Rate Controller" access in the UI...
# 9           Classic  Flight insights and recommendations right on t...
# 10          Classic  Create segments of users based on their politi...
# 11              GSD                    Automated, self-serve analytics
# 12          Classic  Set up Elasticsearch, Logstash, and Kibana for...
# 13              GSD  Let's automate suggesting and applying key opt...
# 14          Classic  Cooperative and Multi-Objective: Solution for ...
# 15          Classic  Let's use our platform/ UI to communicate with...
# 16          Classic  Simple IP address printing program with pseudo...
# 17                   Build a new UI for planning in JIRA to support...
# 18          Classic  Illustration of the challenges in efficiency t...
# 19          Classic  Running native creative ads on mobile devices ...
# 20              GSD  Bulk Modify Creatives. Save Time! Make People ...
# 21          Classic  Easy and fast DCO solution directly in UI with...
# 22              GSD                     Rate Cards available in the UI
# 23              GSD  Alerts that are sent when retargeting performa...
# 24          Classic  Pub/Sub Model for Async Communications among s...
# 25              GSD  Enable sales to access/use marketing emails an...
# 26              GSD  Improve Creative Search so you can search on p...
# 27          Classic  Make a first impression on potential candidate...
# 28          Classic  A Marketplace where you can sell/purchase item...
# 29              GSD  Create an interactive app/map that allows Bost...
# 30          Classic  Create a database for verticals that includes ...
# 31          Classic     "Like" button and Social Networks integration.
#
#                                            Unnamed: 5
# 0                      Team Members (no more than 5!)
# 1   Imran Malek, Jeff Rabe, Aadil Maniar, Gar Smyt...
# 2             Ryan Carey. Louiza Ogbue Leonard Steele
# 3   Ramesh Raithatha\nVineeti Louis\nShruthi Appu\...
# 4   Narin Nhem , GR Vishwanath , Molly Heller , Be...
# 5   Snejana Shegheva, Santiago Carrera, Victoria S...
# 6   Joe Procacci, John Skolfield, Matt Womer, Dave...
# 7   Tom Rue, Looking for all sorts of help! Leonar...
# 8   Bob Brazys is looking for a team - needs: Opti...
# 9   Kim Marchand, Máximo Gurméndez, Martin Bomio, ...
# 10  Saket Mengle, Amit Phansalkar, Ted Vlachos, Mi...
# 11  Emilio Lapiello, Michael Hall, Josh Begleiter,...
# 12            Corey Christous, Dan Lui, Zhuoming Tang
# 13  Amelio Vazquez-Reina, Dan Caddigan, Beth Logan...
# 14          Hui Li, Alessio Gastaldo, Catia Silvestre
# 15                       Berit Block Christel Persson
# 16                      Kenneth Karunia\nNazree Bakar
# 17                    Celia Courtright, Anthony White
# 18                     Bill Mepham. Partners welcome.
# 19                                       Michael Oort
# 20  Eric Mischel, Joe Procacci, Keri Medeiros, Jef...
# 21                          Sascha Becker, Arno Höfer
# 22  Rich Dallojacono, Eric Speck, Manjula Kandasam...
# 23                                            Tom Rue
# 24  Rohit Bhattacharjee\nAmit Pal\nRavi Agarwal\nC...
# 25                Andrew Dudevoir, Dan Reis, Lynn Tan
# 26  Eric Mischel, Joe Procacci, Keri Medeiros, Jef...
# 27  Anjalee Vasvani, Erica Yim, Melinda Tran, Cynt...
# 28  Stephanie Cheung, Tom Lehmann, Mark Ferrandini...
# 29  Peter Buckley, Tyler Kirane, Matt Ferrante, Ma...
# 30  Alex Crow, Patri Freijo, Melinda Tran, Christo...
# 31                          Oleg Lopatin, Raj Hassani

# %%
df.columns.tolist()
# Out:
# ['Judging Session',
#  'Team Name',
#  'Project Home Base (NYC, Bos, Germany, etc.)',
#  'Classic or GSD?',
#  'Quick Description of the project (for recruiting others!)',
#  'Team Members (no more than 5!)',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8']

# %%
df['Team Members (no more than 5!)'].loc[0]
# Out:
# 'We are looking for a team: \t\xe2\x80\xa2\tAlyssa Fedorchak\n\t\xe2\x80\xa2\tBosheng Song'

# %%
fe = feature_transform.FeatureExtractor(f)

# %%
fe.df.members.loc[1]
# Out:
# ['Beth L.\n', 'Narin Nhem\n', 'Karen H.']

# %%
fe.df
# Out:
#    Judging Session                                           location place  \
# 0                                                              Boston   TBD
# 1          BOS-Red                                             Boston   TBD
# 2         BOS-Blue                                             Boston   TBD
# 3        BOS-Green                                             Boston   TBD
# 4          BOS-Red                                    Boston, Uruguay   TBD
# 5          BOS-Red                                             Boston   TBD
# 6        BOS-Green                                             Boston   TBD
# 7         BOS-Blue                                        Boston, TBD   TBD
# 8         BOS-Blue                                             Boston   TBD
# 9        BOS-Green                                             Boston   TBD
# 10         BOS-Red                                             Boston   TBD
# 11        BOS-Blue                                             Boston   TBD
# 12       BOS-Green  New York (with team members in Boston & San Fran)   TBD
# 13         BOS-Red                                             Boston   TBD
# 14           EU-UK                                             London   TBD
# 15           EU-UK                                             London   TBD
# 16        BOS-Blue                                           New York   TBD
# 17       BOS-Green                                           New York   TBD
# 18         BOS-Red                                             Boston   TBD
# 19         BOS-Red                                             Boston   TBD
# 20       BOS-Green                                             Boston   TBD
# 21        BOS-Blue                                           New York   TBD
# 22        BOS-Blue                                             Boston   TBD
# 23       BOS-Green                                             Boston   TBD
# 24         BOS-Red                                             Boston   TBD
# 25        BOS-Blue                                             Boston   TBD
# 26       BOS-Green                                             Boston   TBD
# 27         BOS-Red                                             Boston   TBD
# 28        BOS-Blue                                             Boston   TBD
# 29       BOS-Green                                             Boston   TBD
# 30           EU-UK                                            Cologne   TBD
# 31         BOS-Red                                             Boston   TBD
# 32        BOS-Blue                                             Boston   TBD
#
#                                               members  \
# 0   [We are looking for a team: , Alyssa Fedorchak...
# 1                 [Beth L.\n, Narin Nhem\n, Karen H.]
# 2   [Amelio Vazquez-Reina\n, Terence Lonsdale\n, K...
# 3   [Amelio Vazquez-Reina\n, Beth Logan\n, Anthony...
# 4        [Maximo G\n, Saket M\n, Stacy H\n, Martin B]
# 5   [Snejana Shegheva\n, Shashank Agarwal\n, Chris...
# 6   [Snejana Shegheva\n, Shashank Agarwal\n, Chris...
# 7   [Bobby Mirabello\n, Adam Gurin\n, JB Segal\n, ...
# 8                    [Frank DiCostanzo\n, Dong Jiang]
# 9   [Jad Atoui\n, Thomas Musser\n, Yong Wang\n, Ma...
# 10                                        [Yong Wang]
# 11  [James Baldassari\n, Josh Begleiter\n, Matt Wo...
# 12  [Jessica Bartlett\n, Olivia Shiland\n, Heather...
# 13              [Joe Gosselin\n, Looking for Members]
# 14  [Daniel Sotudeh\n, Stewart Elsey\n, Dhruti Dat...
# 15  [Chris Le May\n, Charlene Fernandez\n, Romana ...
# 16  [▪, Matt Ferrante\n, ▪, John Bronzo\n, ▪, Mari...
# 17  [▪, Dan Caddigan\n, ▪, Craig Belhumeur\n, ▪, T...
# 18                [Siping Liu\n, Looking for Members]
# 19                                                [ ]
# 20                 [Jessica Carneiro\n, Michael Oort]
# 21  [Rich D\n, Anthony White\n, Andy Dale\n, Kevin...
# 22                                      [Imran Malek]
# 23                     [Steve Zesch\n, Yekesa Kosuru]
# 24                                  [Corey Christous]
# 25  [Keri Medeiros\n, Kimberly Marchand\n, Mark Fe...
# 26  [Lauren Masterson\n, Lauren Docktor\n, Molly G...
# 27  [Mick England\n, Joe Gosselin\n, Kris Pearson\...
# 28        [Peter Dana\n, Angfeng Li\n, Bruce Termini]
# 29  [Misha S.\n, Bill D.\n, Jeff L.\n, Graham B.\n...
# 30  [Oliver Bolenius\n, Anja Eckstein\n, Matthias ...
# 31                       [Wes Reing\n, Justin Basque]
# 32                        [Ryan Carey\n, Vinod Rohra]
#
#                          team_name  team_size  \
# 0        People looking for teams!          3
# 1         Algorithm for Algorithms          3
# 2                  D is for DataXu          5
# 3                    Insight Squad          5
# 4                        Think Big          4
# 5                        Six Sigma          4
# 6                  Engineering 3.0          4
# 7                        What's Up          4
# 8                           I2GToo          2
# 9         Third Party Data Tracker          4
# 10       DID (DataXu In-Memory DB)          1
# 11                Anti-Fraud Squad          5
# 12                             TBD          3
# 13       Taking a Stand for Health          2
# 14                       XuRangers          5
# 15                    Data xStream          5
# 16                         Rad Ads         10
# 17                             TBD          6
# 18                             TBD          2
# 19                        DataFits          1
# 20                 Traffic Control          2
# 21          Insert Your Order Here          6
# 22                     DX Tags 2.0          1
# 23  Simplified & Unified Analytics          2
# 24                 Static Analysis          1
# 25                     DataXu News          5
# 26  The Laurens (and anyone else!)          3
# 27                  NOCS\nON\nNOCS          5
# 28                   DB Monitoring          3
# 29                 Cruise Watchers          5
# 30                  DX Creative UX          5
# 31                     DX Sentinel          2
# 32                          Doc It          2
#
#                                                 topic                  style  \
# 0                        people looking for a project                    GSD
# 1   Algorithm recommender - suggest the the right ...          a bit of both
# 2                        Wikipedia article for DataXu                    GSD
# 3   Creation of an insight & visualization squad f...                Classic
# 4   Allows Enterprise clients to use their in-hous...                Classic
# 5   Improve the quality of DX optimizations by cre...                    GSD
# 6         Improve the collaboration process in DataXu  a|GSD> + b|Classical>
# 7   HTML based stream of all things DataXu for int...                    GSD
# 8                  Run Greenplum with AWS I2 instance                Classic
# 9    Inspired by the Domino's Pizza Tracker: http:...                Classic
# 10  Evaluate SAP HANA (and Oracle Times Ten if hav...          A bit of both
# 11  Eliminate bad domains and actors pre-bid and h...                    GSD
# 12  Create a true home page on the DataXu WIKI to ...                    GSD
# 13  Evaluate the benefits and cost effectiveness o...                Classic
# 14  Design an automated end-of-campaign dashboard ...                Classic
# 15            Create customer journey reporting tool.                Classic
# 16                                         Publishers                Classic
# 17                              Creative Bulk Preview                    GSD
# 18  Evaluate mongodb for rts "search" (really look...                classic
# 19  Promote healthy living in the office - Mind bo...                    GSD
# 20  Visualize flight win rates in real time so tha...                Classic
# 21  Create IO/Contract Portal for High Volume Cust...                Classic
# 22  Build ability to add custom metadata / tags to...                Classic
# 23  Unified analytics dashboard for querying and j...                Classic
# 24       Integrate static analysis tools with Jenkins                    GSD
# 25                                   Weekly news show                    GSD
# 26  DataXu on The Beach, both inside and outside t...                    GSD
# 27       Proposal for creating a noc wall for SysEng.                Classic
# 28  Implement a new DB monitoring dashboard by Zab...                Classic
# 29                    Campaign managers and watchers.                    GSD
# 30       Creative UX on creative and report category.                Classic
# 31             Easily Configure Monitoring End Points                Classic
# 32  Create a web service for storing and managing ...                    GSD
#
#    innovation_day
# 0           inno8
# 1           inno8
# 2           inno8
# 3           inno8
# 4           inno8
# 5           inno8
# 6           inno8
# 7           inno8
# 8           inno8
# 9           inno8
# 10          inno8
# 11          inno8
# 12          inno8
# 13          inno8
# 14          inno8
# 15          inno8
# 16          inno8
# 17          inno8
# 18          inno8
# 19          inno8
# 20          inno8
# 21          inno8
# 22          inno8
# 23          inno8
# 24          inno8
# 25          inno8
# 26          inno8
# 27          inno8
# 28          inno8
# 29          inno8
# 30          inno8
# 31          inno8
# 32          inno8

# %%
fe.df.members.apply(lambda x: len(''.join(x)))
# Out:
# 0      56
# 1      27
# 2      80
# 3      74
# 4      33
# 5      57
# 6      57
# 7     117
# 8      27
# 9      45
# 10      9
# 11     66
# 12     43
# 13     32
# 14     73
# 15     73
# 16     59
# 17     49
# 18     30
# 19      2
# 20     29
# 21     90
# 22     11
# 23     25
# 24     15
# 25     72
# 26     45
# 27     75
# 28     35
# 29     42
# 30     75
# 31     23
# 32     22
# Name: members, dtype: int64
